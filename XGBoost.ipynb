# %%
import os
import numpy as np
import pandas as pd
import shutil
from shutil import copyfile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
source_path = "/content/drive/Shareddrives/Braille_Project/Braille_Project/output/"

paths = {}

alpha = np.array(['அ','ஆ','இ','ஈ','உ','ஊ','எ','ஏ','ஐ','ஒ','ஓ','ஒள','ஃ','க','ங','ச','ஞ','ட','ண','த','ந','ப','ம','ய','ர','ல','வ','ழ','ள','ற','ன'])

for i in alpha:
  paths[i] = os.path.join(source_path, i)
  print(f"Number of images in {i} directory : "+str(len(os.listdir(paths[i]))))
# Out:
# Number of images in அ directory : 350
# Number of images in ஆ directory : 350
# Number of images in இ directory : 348
# Number of images in ஈ directory : 350
# Number of images in உ directory : 349
# Number of images in ஊ directory : 350
# Number of images in எ directory : 350
# Number of images in ஏ directory : 349
# Number of images in ஐ directory : 349
# Number of images in ஒ directory : 347
# Number of images in ஓ directory : 348
# Number of images in ஒள directory : 350
# Number of images in ஃ directory : 350
# Number of images in க directory : 350
# Number of images in ங directory : 349
# Number of images in ச directory : 349
# Number of images in ஞ directory : 348
# Number of images in ட directory : 348
# Number of images in ண directory : 349
# Number of images in த directory : 350
# Number of images in ந directory : 350
# Number of images in ப directory : 349
# Number of images in ம directory : 349
# Number of images in ய directory : 350
# Number of images in ர directory : 349
# Number of images in ல directory : 348
# Number of images in வ directory : 350
# Number of images in ழ directory : 350
# Number of images in ள directory : 350
# Number of images in ற directory : 349
# Number of images in ன directory : 350

# %%
base_dir = "/content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets"

if os.path.exists(base_dir):
  shutil.rmtree(base_dir)

def mk_train_val_dirs(base_path):
  for i in alpha :
    os.makedirs(os.path.join(base_path,'training/'+i))
    os.makedirs(os.path.join(base_path,'validation/'+i))

mk_train_val_dirs(base_dir)

# %%
for rootdir, dirs, files in os.walk(base_dir):
    for subdir in dirs:
        print(os.path.join(rootdir, subdir))
# Out:
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/அ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஆ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/இ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஈ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/உ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஊ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/எ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஏ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஐ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஒ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஓ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஒள
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஃ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/க
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ங
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ச
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ஞ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ட
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ண
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/த
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ந
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ப
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ம
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ய
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ர
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ல
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/வ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ழ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ள
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ற
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/ன
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/அ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஆ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/இ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஈ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/உ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஊ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/எ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஏ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஐ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஒ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஓ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஒள
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஃ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/க
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ங
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ச
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ஞ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ட
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ண
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/த
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ந
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ப
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ம
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ய
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ர
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ல
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/வ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ழ
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ள
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ற
# /content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/ன

# %%
import random
from tensorflow.keras.utils import load_img, img_to_array

def split_data(SOURCE_DIR, TRAINING_DIR, VALIDATION_DIR, SPLIT_SIZE):

  raw_data = os.listdir(SOURCE_DIR)
  clean_data = []
  for i in raw_data :
    if os.path.getsize(os.path.join(SOURCE_DIR,i))==0 :
      print(i+" is zero length, so ignoring.")
    else :
      clean_data.append(i)

  len_clean_data = len(clean_data)
  len_train_data = len_clean_data*SPLIT_SIZE
  train_data = random.sample(clean_data, int(len_train_data))
  for i in train_data :
    copyfile(os.path.join(SOURCE_DIR,i),os.path.join(TRAINING_DIR,i))
  for i in clean_data :
    if i not in train_data :
      copyfile(os.path.join(SOURCE_DIR,i),os.path.join(VALIDATION_DIR,i))

# %%
TRAINING_DIR = "/content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training"
VALIDATION_DIR = "/content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation"

SOURCE_DIR = "/content/drive/Shareddrives/Braille_Project/Braille_Project/output"

# Empty directories in case you run this cell multiple times

for i in alpha :
  if len(os.listdir(os.path.join(TRAINING_DIR,i))) > 0:
    for file in os.scandir(os.path.join(TRAINING_DIR,i)):
      os.remove(file.path)
  if len(os.listdir(os.path.join(VALIDATION_DIR,i))) > 0:
    for file in os.scandir(os.path.join(VALIDATION_DIR,i)):
      os.remove(file.path)

split_size = .8

for i in alpha :
  split_data(os.path.join(SOURCE_DIR,i), os.path.join(TRAINING_DIR,i), os.path.join(VALIDATION_DIR,i), split_size)


for i in alpha:
  print(f"Source {i} directory has {len(os.listdir(os.path.join(SOURCE_DIR,i)))} images")
  print(f"Training {i} directory has {len(os.listdir(os.path.join(TRAINING_DIR,i)))} images")
  print(f"Validation {i} directory has {len(os.listdir(os.path.join(VALIDATION_DIR,i)))} images\n")
# Out:
# Source அ directory has 350 images
# Training அ directory has 280 images
# Validation அ directory has 70 images
#
# Source ஆ directory has 350 images
# Training ஆ directory has 280 images
# Validation ஆ directory has 70 images
#
# Source இ directory has 348 images
# Training இ directory has 278 images
# Validation இ directory has 70 images
#
# Source ஈ directory has 350 images
# Training ஈ directory has 280 images
# Validation ஈ directory has 70 images
#
# Source உ directory has 349 images
# Training உ directory has 279 images
# Validation உ directory has 70 images
#
# Source ஊ directory has 350 images
# Training ஊ directory has 280 images
# Validation ஊ directory has 70 images
#
# Source எ directory has 350 images
# Training எ directory has 280 images
# Validation எ directory has 70 images
#
# Source ஏ directory has 349 images
# Training ஏ directory has 279 images
# Validation ஏ directory has 70 images
#
# Source ஐ directory has 349 images
# Training ஐ directory has 279 images
# Validation ஐ directory has 70 images
#
# Source ஒ directory has 347 images
# Training ஒ directory has 277 images
# Validation ஒ directory has 70 images
#
# Source ஓ directory has 348 images
# Training ஓ directory has 278 images
# Validation ஓ directory has 70 images
#
# Source ஒள directory has 350 images
# Training ஒள directory has 280 images
# Validation ஒள directory has 70 images
#
# Source ஃ directory has 350 images
# Training ஃ directory has 280 images
# Validation ஃ directory has 70 images
#
# Source க directory has 350 images
# Training க directory has 280 images
# Validation க directory has 70 images
#
# Source ங directory has 349 images
# Training ங directory has 279 images
# Validation ங directory has 70 images
#
# Source ச directory has 349 images
# Training ச directory has 279 images
# Validation ச directory has 70 images
#
# Source ஞ directory has 348 images
# Training ஞ directory has 278 images
# Validation ஞ directory has 70 images
#
# Source ட directory has 348 images
# Training ட directory has 278 images
# Validation ட directory has 70 images
#
# Source ண directory has 349 images
# Training ண directory has 279 images
# Validation ண directory has 70 images
#
# Source த directory has 350 images
# Training த directory has 280 images
# Validation த directory has 70 images
#
# Source ந directory has 350 images
# Training ந directory has 280 images
# Validation ந directory has 70 images
#
# Source ப directory has 349 images
# Training ப directory has 279 images
# Validation ப directory has 70 images
#
# Source ம directory has 349 images
# Training ம directory has 279 images
# Validation ம directory has 70 images
#
# Source ய directory has 350 images
# Training ய directory has 280 images
# Validation ய directory has 70 images
#
# Source ர directory has 349 images
# Training ர directory has 279 images
# Validation ர directory has 70 images
#
# Source ல directory has 348 images
# Training ல directory has 278 images
# Validation ல directory has 70 images
#
# Source வ directory has 350 images
# Training வ directory has 280 images
# Validation வ directory has 70 images
#
# Source ழ directory has 350 images
# Training ழ directory has 280 images
# Validation ழ directory has 70 images
#
# Source ள directory has 350 images
# Training ள directory has 280 images
# Validation ள directory has 70 images
#
# Source ற directory has 349 images
# Training ற directory has 279 images
# Validation ற directory has 70 images
#
# Source ன directory has 350 images
# Training ன directory has 280 images
# Validation ன directory has 70 images

# %%
from keras.preprocessing.image import ImageDataGenerator
training_images = ImageDataGenerator(rescale=1./255.,
                                      fill_mode='nearest')

train_generator = training_images.flow_from_directory("/content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/training/",
                                                      shuffle=False,
                                                      target_size=(28,28))

validation_images = ImageDataGenerator(rescale=1./255.,
                                      fill_mode='nearest')

val_generator = validation_images.flow_from_directory("/content/drive/Shareddrives/Braille_Project/Braille_Project/Datasets/validation/",
                                                      shuffle=False,
                                                      target_size=(28,28))
# Out:
# Found 8657 images belonging to 31 classes.
# Found 2170 images belonging to 31 classes.

# %%
from keras import backend as K
from keras import layers as L
from keras.models import Model,load_model
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint,ReduceLROnPlateau,EarlyStopping

K.clear_session()

model_ckpt = ModelCheckpoint('/content/drive/Shareddrives/Braille_Project/Braille_Project/Models/Final_Model/BrailleNet.h5',save_best_only=True)
reduce_lr = ReduceLROnPlateau(patience=8,verbose=0)
early_stop = EarlyStopping(patience=15,verbose=1)

entry = L.Input(shape=(28,28,3))
x = L.SeparableConv2D(64,(3,3),activation='relu')(entry)
x = L.MaxPooling2D((2,2))(x)
x = L.SeparableConv2D(128,(3,3),activation='relu')(x)
x = L.MaxPooling2D((2,2))(x)
x = L.SeparableConv2D(256,(2,2),activation='relu')(x)
x = L.GlobalMaxPooling2D()(x)
x = L.Dense(256)(x)

model = Model(entry,x)

# %%
train_output = model.predict(train_generator) 
train_output = pd.DataFrame(data=train_output)
train_label = train_generator.classes
# Out:
# 271/271 [==============================] - 24s 86ms/step

# %%
val_output = model.predict(val_generator) 
val_output = pd.DataFrame(data=val_output)
val_label = val_generator.classes
# Out:
# 68/68 [==============================] - 10s 141ms/step

# %%
from xgboost import XGBClassifier

xgbmodel = XGBClassifier(objective='multi:softprob', 
                      num_class= 31)
history = xgbmodel.fit(train_output, train_label)

# %%
xgbmodel.score(val_output, val_label)
# Out:
# 0.8755760368663594
